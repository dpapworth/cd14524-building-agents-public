# %% [markdown]
# # [STARTER] Exercise - Building an Agentic RAG System
#
# In this exercise, you will build an Agentic RAG (Retrieval-Augmented Generation) system that
# combines the power of AI agents with traditional RAG pipelines. You'll create an agent that
# can decide when and how to retrieve information from different sources, including vector
# databases, web search, and other tools.

# %% [markdown]
# ## Challenge
#
# Your challenge is to create an Agentic RAG system that can:
#
# - Build a RAG pipeline as a tool that can be used by the agent
# - Create an agent that can decide which tool to use based on the query
# - Handle different types of queries intelligently
# - Combine information from multiple sources when needed

# %% [markdown]
# ## Setup
# First, let's import the necessary libraries:

# %%
# Only needed for Udacity workspace

import importlib.util
import sys

# Check if 'pysqlite3' is available before importing
if importlib.util.find_spec("pysqlite3") is not None:
    import pysqlite3
    sys.modules['sqlite3'] = sys.modules.pop('pysqlite3')

# %%
import os
from typing import List
from dotenv import load_dotenv

from lib.agents import Agent
from lib.llm import LLM
from lib.state_machine import Run
from lib.messages import BaseMessage
from lib.tooling import tool
from lib.vector_db import VectorStoreManager, CorpusLoaderService
from lib.rag import RAG

# %%
load_dotenv()
# Out:
# True

# %%
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ## Load data to Vector DB

# %%
db = VectorStoreManager(OPENAI_API_KEY)
db
# Out:
# VectorStoreManager():<chromadb.api.client.Client object at 0x7e5b5ff03620>

# %%
loader_service = CorpusLoaderService(db)

# %%
rag_llm = LLM(
    model="gpt-4o-mini",
    temperature=0.3,
)

# %%
# DONE: Add the games pdf file path with the extension .pdf
# And define a store name in load_pdf() method

games_market_rag = RAG(
    llm=rag_llm,
    vector_store = loader_service.load_pdf("gaming_industry", "TheGamingIndustry2024.pdf")
)
# Out:
# VectorStore `gaming_industry` ready!
# Pages from `TheGamingIndustry2024.pdf` added!

# %%
result:Run = games_market_rag.invoke(
    "What's the  state of virtual reality"
)
print(result.get_final_state()["answer"])
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# The state of virtual reality (VR) in 2024 is characterized by significant advancements and immersive experiences that enhance gaming. VR technology allows players to fully engage in digital environments, offering realistic interactions and sensory engagement. Games like "Half-Life: Alyx" exemplify this trend by providing high-fidelity graphics and intuitive controls that immerse players in compelling narratives. Additionally, VR is being integrated into educational settings, enhancing learning through immersive experiences. Overall, VR is reshaping the gaming landscape and expanding its applications beyond entertainment into areas like education and mental health.

# %%
# DONE: Add the electric vehicles pdf file path with the extension .pdf
# And define a store name in load_pdf() method

electric_vehicles_rag = RAG(
    llm=rag_llm,
    vector_store = loader_service.load_pdf("global_ev_outlook", "GlobalEVOutlook2025.pdf")
)
# Out:
# VectorStore `global_ev_outlook` ready!
# Pages from `GlobalEVOutlook2025.pdf` added!

# %%
result:Run = electric_vehicles_rag.invoke("What was the number of electric car sales and their market share in Brazil in 2024?")
print(result.get_final_state()["answer"])
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# In 2024, Brazil saw nearly 125,000 electric car sales, which represented a market share of 6.5%.

# %% [markdown]
# ## Tools
#
# In a simple form, Agentic RAG can act like a router, choosing between multiple external sources to retrieve relevant information. These sources aren't limited to databases, they can also include tools like web search or APIs for services such as Slack or email.
#
# In this case it will choose between two collections.

# %%
# DONE: Define a tool that returns result.get_final_state()["answer"]
# DO NOT Forget about defining the tool docstrings
@tool
def search_global_ev_collection(query):
    """
    Ask questions about global EV outlook.

    args:
        query (str): Search query
    """
    result:Run = electric_vehicles_rag.invoke(query)
    return result.get_final_state()["answer"]

# %%
# DONE: Define a tool that returns result.get_final_state()["answer"]
# DO NOT Forget about defining the tool docstrings
@tool
def search_games_market_report_collection(query):
    """
    Ask questions about the game development industry.

    args:
        query (str): Search query
    """
    result:Run = games_market_rag.invoke(query)
    return result.get_final_state()["answer"]

# %%
# DONE: Add the tools you have defined and the instructions to your agent
agentic_rag = Agent(
    model_name="gpt-4o-mini",
    tools=[search_global_ev_collection, search_games_market_report_collection],    
    instructions="""
You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions.
Reason about the response, change the query and call the tool again if needed in order to get better results.
Always explain your reasoning for tool selection and provide comprehensive answers.
"""
)

# %%
def print_messages(messages: List[BaseMessage]):
    for m in messages: 
        print(f" -> (role = {m.role}, content = {m.content}, tool_calls = {getattr(m, 'tool_calls', None)})")

# %% [markdown]
# ## Run

# %%
run_1 = agentic_rag.invoke(
    query="Who won the 2025 Oscar for International Movie?", 
    session_id="oscar",
)

print("\nMessages from run 1:")
messages = run_1.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 1:
#  -> (role = system, content =
# You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions.
# Reason about the response, change the query and call the tool again if needed in order to get better results.
# Always explain your reasoning for tool selection and provide comprehensive answers.
# , tool_calls = None)
#  -> (role = user, content = Who won the 2025 Oscar for International Movie?, tool_calls = None)
#  -> (role = assistant, content = The 2025 Oscars have not yet occurred, as they are scheduled for March 2025. Therefore, I cannot provide the winner for the Oscar for International Movie in 2025. If you have any other questions or need information about previous Oscar winners or nominations, feel free to ask!, tool_calls = None)

# %%
run_2 = agentic_rag.invoke(
    query= (
        "Which two countries accounted for most of the electric car exports from " 
        "the Asia Pacific region (excluding China) in 2024?"
    ),
    session_id="electric_car",
)

print("\nMessages from run 2:")
messages = run_2.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 2:
#  -> (role = system, content =
# You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions.
# Reason about the response, change the query and call the tool again if needed in order to get better results.
# Always explain your reasoning for tool selection and provide comprehensive answers.
# , tool_calls = None)
#  -> (role = user, content = Which two countries accounted for most of the electric car exports from the Asia Pacific region (excluding China) in 2024?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_nktVsobiJk1HqT768tYKINMk', function=Function(arguments='{"query":"electric car exports Asia Pacific region 2024 excluding China"}', name='search_global_ev_collection'), type='function')])
#  -> (role = tool, content = "In 2024, Japan and Korea accounted for the majority of the nearly 640,000 electric cars exported from the Asia Pacific region excluding China, marking an increase of 15% from 2023. The United States was the main destination for these exports, making up more than a quarter of the total production in the region. Europe followed as the second-largest market, importing another quarter of the region's electric car production.", tool_calls = None)
#  -> (role = assistant, content = In 2024, Japan and Korea were the two countries that accounted for most of the electric car exports from the Asia Pacific region, excluding China. Together, they contributed to nearly 640,000 electric cars exported, reflecting a 15% increase from the previous year. The primary destination for these exports was the United States, followed by Europe as the second-largest market., tool_calls = None)

# %%
run_3 = agentic_rag.invoke(
    query= (
        "Why is generative AI seen more as an accelerator than a replacement in game development?"
    ),
    session_id="games",
)

print("\nMessages from run 3:")
messages = run_3.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 3:
#  -> (role = system, content =
# You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions.
# Reason about the response, change the query and call the tool again if needed in order to get better results.
# Always explain your reasoning for tool selection and provide comprehensive answers.
# , tool_calls = None)
#  -> (role = user, content = Why is generative AI seen more as an accelerator than a replacement in game development?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_PnFErvLgJXIEUFm3Nul2Dv5N', function=Function(arguments='{"query":"generative AI accelerator replacement game development"}', name='search_games_market_report_collection'), type='function')])
#  -> (role = tool, content = "I don't know.", tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_GxEfk38MERs6aVMDEiBbfN1J', function=Function(arguments='{"query":"impact of generative AI on game development"}', name='search_games_market_report_collection'), type='function')])
#  -> (role = tool, content = "The impact of generative AI on game development is significant, as it enhances various aspects of the gaming experience. AI is utilized in designing, developing, and improving games, allowing for the simulation of intelligent behavior and the automation of complex tasks. This leads to more dynamic and responsive gaming environments, particularly through the development of non-player characters (NPCs) that can react in real-time to player actions, thereby adding depth and realism to gameplay. For example, games like \"The Last of Us\" showcase AI's ability to create realistic behaviors in both opponents and companions, marking it as a crucial innovation in modern gaming. Overall, the integration of AI is reshaping the gaming industry, which is valued at approximately $200 billion.", tool_calls = None)
#  -> (role = assistant, content = Generative AI is increasingly viewed as an accelerator rather than a replacement in game development for several key reasons:
#
# 1. **Enhancement of Creativity**: Generative AI tools assist developers by providing creative suggestions and automating repetitive tasks, allowing teams to focus on more complex and imaginative aspects of game design. This enhances the creative process rather than replacing human creativity.
#
# 2. **Dynamic Environments**: AI can simulate intelligent behaviors, particularly in non-player characters (NPCs), making gaming environments more responsive and lifelike. This adds depth to gameplay, as seen in games like "The Last of Us," where AI contributes to realistic interactions between characters.
#
# 3. **Efficiency in Development**: By automating certain design elements and streamlining workflows, generative AI can significantly speed up the development process. This efficiency allows developers to bring their visions to life more quickly and with fewer resources, rather than rendering their roles obsolete.
#
# 4. **Collaboration with Human Developers**: Generative AI is designed to work alongside human developers, complementing their skills. It acts as a tool that enhances productivity and creativity, rather than serving as a substitute for the nuanced understanding and emotional intelligence that human developers bring to game design.
#
# Overall, generative AI empowers developers to innovate and optimize their work processes, making it an invaluable asset in the evolving landscape of game development. This collaborative role highlights why it's seen more as an accelerator than a replacement., tool_calls = None)
